# %%
import pandas as pd

df = pd.read_csv("../data/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (768, 9)

# %%
print(f"pregnancies: {df.Pregnancies.count()}")
# Out:
# pregnancies: 768

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
from scipy import stats
r, p = stats.pearsonr(df.Glucose, df.Outcome)
print(round(r, 4))
print(round(p, 42))
# Out:
# 0.4666
# 1e-42

# %%
import matplotlib.pyplot as plt 
plt.scatter(df.SkinThickness, df.BMI) 
plt.title('Skin Thicknes vs BMI')
plt.xlabel('Skin thicknes')
plt.ylabel('BMI')
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.scatter(df.Insulin, df.Glucose) 
plt.title('Insulin vs Glucose')
plt.xlabel('Insulin')
plt.ylabel('Glucose')
plt.show()

# %%
df_diabetes = df[df['Outcome'] == 1]
df_nodiabetes = df[df['Outcome'] == 0]

plt.scatter(df_diabetes.Age, df_diabetes.Glucose, label='Diabetes: positive')
plt.scatter(df_nodiabetes.Age, df_nodiabetes.Glucose, label='Diabetes: negative')
plt.xlabel('Age')
plt.ylabel('Glucose')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.scatter(df.BMI, df.Glucose)
plt.title('BMI vs Glucose')
plt.xlabel('BMI')
plt.ylabel('Glucose')
plt.show()

# %%
from scipy import stats 

def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return df[(df[column] >= lower) & (df[column] <= upper)]

df_clean = remove_outliers_iqr(df, 'BMI')
df_clean = remove_outliers_iqr(df_clean, 'Glucose')

m, b, r, p, err = stats.linregress(df.BMI, df.Glucose)

x = range(18, 51)
y = m * x + b
plt.plot(x, y, color='black')
plt.scatter(df_clean.BMI, df_clean.Glucose)
plt.title('BMI vs Glucose')
plt.xlabel('BMI')
plt.ylabel('Glucose')
plt.grid(True)
plt.show()

# %%
from statsmodels.stats.diagnostic import het_breuschpagan 
from statsmodels.stats.diagnostic import het_white
from statsmodels.formula.api import ols 

model = ols(formula='Glucose~BMI', data=df).fit()

white_test = het_white(model.resid, model.model.exog)
breushpagan_test = het_breuschpagan(model.resid, model.model.exog)

output_df = pd.DataFrame(columns=['LM stat', 'LM p', 'F stat', 'F stat p'])
output_df.loc['White'] = white_test
output_df.loc['Breusch-Pagan'] = breushpagan_test

output_df
# Out:
#                 LM stat      LM p    F stat  F stat p
# White          5.169055  0.075432  2.591876  0.075537
# Breusch-Pagan  4.527046  0.033363  4.542030  0.033390

# %%
import seaborn as sns 
sns.set(color_codes=True)
sns.jointplot(x="BMI", y="Glucose", data=df);

# %%
sns.jointplot(x="BMI", y="Glucose", data=df, kind="hex")

# %%
sns.jointplot(x="BMI", y="Glucose", data=df, kind="kde")

# %%
f, ax = plt.subplots(figsize=(8,6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=False)
sns.kdeplot(x=df.BMI, y=df.Glucose, cmap=cmap, n_levels=60, fill=True)
# Out:
# <Axes: xlabel='BMI', ylabel='Glucose'>

# %%
df.dropna(inplace=True)
sns.pairplot(df);

# %%
g = sns.PairGrid(df)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot,n_levels=10)

# %%
import pandas as pd
import plotly.express as px
fig = px.scatter_3d(df, x='BMI', y='Glucose', z='bmi')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 3
#       1 import pandas as pd
#       2 import plotly.express as px
# ----> 3 fig = px.scatter_3d(df, x='age', y='charges', z='bmi')
#       4 fig.show()
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_chart_types.py:776, in scatter_3d(data_frame, x, y, z, color, symbol, size, text, hover_name, hover_data, custom_data, error_x, error_x_minus, error_y, error_y_minus, error_z, error_z_minus, animation_frame, animation_group, category_orders, labels, size_max, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, log_x, log_y, log_z, range_x, range_y, range_z, title, template, width, height)
#     730 def scatter_3d(
#     731     data_frame=None,
#     732     x=None,
#    (...)
#     770     height=None,
# ...
